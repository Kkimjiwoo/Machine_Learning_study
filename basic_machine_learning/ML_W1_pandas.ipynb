# %% [markdown]
# # pandas 기본 문법

# %%
import pandas as pd

# %% [markdown]
# # **pandas 테이블 구조**
#
# ![01_table_dataframe.svg](data:image/svg+xml;base64,...)

# %%
# 데이터 프레임 만들기
df = pd.DataFrame(
    {
        'NAME':[
            '김지우',
            '김철수'
            ],
        'AGE':[20,30],
        'SEX':['M','F']
    }
)

df
# Out:
#   NAME  AGE SEX
# 0  김지우   20   M
# 1  김철수   30   F

# %%
# 데이터 프레임 내 하나의 컬럼 보기
df['SEX']
# Out:
# 0    M
# 1    F
# Name: SEX, dtype: object

# %%
# Series 만들기
ages = pd.Series([20,30,50], name = 'Age')

# %%
# series 확인하기
ages
# Out:
# 0    20
# 1    30
# 2    50
# Name: Age, dtype: int64

# %%
df['AGE'].max()
# Out:
# 30

# %%
ages.max()
# Out:
# 50

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/mulcam_bigdata/data
# Out:
# /content/drive/MyDrive/mulcam_bigdata/data

# %%
pd.read_csv('Advertising.csv')
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
ad = pd.read_csv('Advertising.csv')

# %%
ad.head(3)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3

# %%
ad.tail(3)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
# 데이터 타입 보기
ad.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# Radio         float64
# Newspaper     float64
# Sales         float64
# dtype: object

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
# 파일로 저장
ad.to_csv("/content/Advertising_new.csv")
